# %%
import pandas as pd

# %%
# Visualizando dados que serão limpos 
data = pd.read_csv("ocorrencia_modificado.csv")
data.head()
# Out:
#    Unnamed: 0  codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0           0              52242               52242                INCIDENTE
# 1           1              45331               45331                 ACIDENTE
# 2           2              45333               45333                 ACIDENTE
# 3           3              45401               45401                 ACIDENTE
# 4           4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
# 4          SÃO SEPÉ            RS                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0
# 4        16:30:00                    0

# %%
data.loc[1,'ocorrencia_cidade']
# Out:
# 'GUARULHOS'

# %%
data.loc[1:3]
# Out:
#    Unnamed: 0  codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1           1              45331               45331                 ACIDENTE
# 2           2              45333               45333                 ACIDENTE
# 3           3              45401               45401                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0

# %%
data.loc[[10,40]]
# Out:
#     Unnamed: 0  codigo_ocorrencia  codigo_ocorrencia2  \
# 10          10              45332               45332
# 40          40              45415               45415
#
#    ocorrencia_classificacao ocorrencia_cidade ocorrencia_uf  \
# 10                 ACIDENTE            VIAMÃO            RS
# 40                 ACIDENTE    RIO DE JANEIRO            RJ
#
#    ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 10                 ****     2012-01-09        13:30:00                    0
# 40                 ****     2012-01-30        13:55:00                    0

# %%
data.loc[:,'ocorrencia_cidade']
# Out:
# 0        PORTO ALEGRE
# 1           GUARULHOS
# 2              VIAMÃO
# 3       SÃO SEBASTIÃO
# 4            SÃO SEPÉ
#             ...
# 5162            JATAÍ
# 5163          MARACAÍ
# 5164    NOVO HAMBURGO
# 5165         CURITIBA
# 5166        PETROLINA
# Name: ocorrencia_cidade, Length: 5167, dtype: object

# %%
data.codigo_ocorrencia.is_unique
# Out:
# True

# %%
data.head()
# Out:
#    Unnamed: 0  codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0           0              52242               52242                INCIDENTE
# 1           1              45331               45331                 ACIDENTE
# 2           2              45333               45333                 ACIDENTE
# 3           3              45401               45401                 ACIDENTE
# 4           4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
# 4          SÃO SEPÉ            RS                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0
# 4        16:30:00                    0

# %%
data.loc[4032]
# Out:
# Unnamed: 0                        4032
# codigo_ocorrencia                78989
# codigo_ocorrencia2               78989
# ocorrencia_classificacao     INCIDENTE
# ocorrencia_cidade             CAMPINAS
# ocorrencia_uf                       SP
# ocorrencia_aerodromo             *****
# ocorrencia_dia              2019-10-24
# ocorrencia_hora               17:40:00
# total_recomendacoes                  0
# Name: 4032, dtype: object

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.head()
# Out:
#    Unnamed: 0  codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0           0              52242               52242                INCIDENTE
# 1           1              45331               45331                 ACIDENTE
# 2           2              45333               45333                 ACIDENTE
# 3           3              45401               45401                 ACIDENTE
# 4           4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1         GUARULHOS            SP                 SBGR     2012-01-06
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
# 4          SÃO SEPÉ            RS                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1        13:44:00                    3
# 2        13:00:00                    0
# 3        17:00:00                    0
# 4        16:30:00                    0

# %%
data.loc[0,'ocorrencia_aerodromo'] = ''

# %%
data.head(1)
# Out:
#    Unnamed: 0  codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0           0              52242               52242                INCIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                          2012-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0

# %%
data.loc[1] = 20

# %%
data.head(2)
# Out:
#    Unnamed: 0  codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0           0              52242               52242                INCIDENTE
# 1          20                 20                  20                       20
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                          2012-01-05
# 1                20            20                   20             20
#
#   ocorrencia_hora  total_recomendacoes
# 0        20:27:00                    0
# 1              20                   20

# %%
data.loc[:,'total_recomendacoes'] = 10

# %%
data
# Out:
#       Unnamed: 0  codigo_ocorrencia  codigo_ocorrencia2  \
# 0              0              52242               52242
# 1             20                 20                  20
# 2              2              45333               45333
# 3              3              45401               45401
# 4              4              45407               45407
# ...          ...                ...                 ...
# 5162        5162              80458               80458
# 5163        5163              80452               80452
# 5164        5164              80457               80457
# 5165        5165              80460               80460
# 5166        5166              80467               80467
#
#      ocorrencia_classificacao ocorrencia_cidade ocorrencia_uf  \
# 0                   INCIDENTE      PORTO ALEGRE            RS
# 1                          20                20            20
# 2                    ACIDENTE            VIAMÃO            RS
# 3                    ACIDENTE     SÃO SEBASTIÃO            SP
# 4                    ACIDENTE          SÃO SEPÉ            RS
# ...                       ...               ...           ...
# 5162                 ACIDENTE             JATAÍ            GO
# 5163                 ACIDENTE           MARACAÍ            SP
# 5164          INCIDENTE GRAVE     NOVO HAMBURGO            RS
# 5165                INCIDENTE          CURITIBA            PR
# 5166                INCIDENTE         PETROLINA            PE
#
#      ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0                             2012-01-05        20:27:00                   10
# 1                      20             20              20                   10
# 2                    ****     2012-01-06        13:00:00                   10
# 3                    ****     2012-01-06        17:00:00                   10
# 4                    ****     2012-01-06        16:30:00                   10
# ...                   ...            ...             ...                  ...
# 5162                 ####     2021-12-30        20:30:00                   10
# 5163                *****     2021-12-31        09:30:00                   10
# 5164                 SSNH     2021-12-31        11:59:00                   10
# 5165                 SBBI     2021-12-31        15:12:00                   10
# 5166                 SBPL     2021-12-31        20:30:00                   10
#
# [5167 rows x 10 columns]

# %%
data['ocorrencia_uf_bkp'] = data.ocorrencia_uf

# %%
data
# Out:
#       Unnamed: 0  codigo_ocorrencia  codigo_ocorrencia2  \
# 0              0              52242               52242
# 1             20                 20                  20
# 2              2              45333               45333
# 3              3              45401               45401
# 4              4              45407               45407
# ...          ...                ...                 ...
# 5162        5162              80458               80458
# 5163        5163              80452               80452
# 5164        5164              80457               80457
# 5165        5165              80460               80460
# 5166        5166              80467               80467
#
#      ocorrencia_classificacao ocorrencia_cidade ocorrencia_uf  \
# 0                   INCIDENTE      PORTO ALEGRE            RS
# 1                          20                20            20
# 2                    ACIDENTE            VIAMÃO            RS
# 3                    ACIDENTE     SÃO SEBASTIÃO            SP
# 4                    ACIDENTE          SÃO SEPÉ            RS
# ...                       ...               ...           ...
# 5162                 ACIDENTE             JATAÍ            GO
# 5163                 ACIDENTE           MARACAÍ            SP
# 5164          INCIDENTE GRAVE     NOVO HAMBURGO            RS
# 5165                INCIDENTE          CURITIBA            PR
# 5166                INCIDENTE         PETROLINA            PE
#
#      ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes  \
# 0                             2012-01-05        20:27:00                   10
# 1                      20             20              20                   10
# 2                    ****     2012-01-06        13:00:00                   10
# 3                    ****     2012-01-06        17:00:00                   10
# 4                    ****     2012-01-06        16:30:00                   10
# ...                   ...            ...             ...                  ...
# 5162                 ####     2021-12-30        20:30:00                   10
# 5163                *****     2021-12-31        09:30:00                   10
# 5164                 SSNH     2021-12-31        11:59:00                   10
# 5165                 SBBI     2021-12-31        15:12:00                   10
# 5166                 SBPL     2021-12-31        20:30:00                   10
#
#      ocorrencia_uf_bkp
# 0                   RS
# 1                   20
# 2                   RS
# 3                   SP
# 4                   RS
# ...                ...
# 5162                GO
# 5163                SP
# 5164                RS
# 5165                PR
# 5166                PE
#
# [5167 rows x 11 columns]

# %%
data.loc[data.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
data
# Out:
#       Unnamed: 0  codigo_ocorrencia  codigo_ocorrencia2  \
# 0              0              52242               52242
# 1             20                 20                  20
# 2              2              45333               45333
# 3              3              45401               45401
# 4              4              45407               45407
# ...          ...                ...                 ...
# 5162        5162              80458               80458
# 5163        5163              80452               80452
# 5164        5164              80457               80457
# 5165        5165              80460               80460
# 5166        5166              80467               80467
#
#      ocorrencia_classificacao ocorrencia_cidade ocorrencia_uf  \
# 0                   INCIDENTE      PORTO ALEGRE            RS
# 1                          20                20            20
# 2                    ACIDENTE            VIAMÃO            RS
# 3                       GRAVE     SÃO SEBASTIÃO            SP
# 4                    ACIDENTE          SÃO SEPÉ            RS
# ...                       ...               ...           ...
# 5162                 ACIDENTE             JATAÍ            GO
# 5163                    GRAVE           MARACAÍ            SP
# 5164          INCIDENTE GRAVE     NOVO HAMBURGO            RS
# 5165                INCIDENTE          CURITIBA            PR
# 5166                INCIDENTE         PETROLINA            PE
#
#      ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes  \
# 0                             2012-01-05        20:27:00                   10
# 1                      20             20              20                   10
# 2                    ****     2012-01-06        13:00:00                   10
# 3                    ****     2012-01-06        17:00:00                   10
# 4                    ****     2012-01-06        16:30:00                   10
# ...                   ...            ...             ...                  ...
# 5162                 ####     2021-12-30        20:30:00                   10
# 5163                *****     2021-12-31        09:30:00                   10
# 5164                 SSNH     2021-12-31        11:59:00                   10
# 5165                 SBBI     2021-12-31        15:12:00                   10
# 5166                 SBPL     2021-12-31        20:30:00                   10
#
#      ocorrencia_uf_bkp
# 0                   RS
# 1                   20
# 2                   RS
# 3                   SP
# 4                   RS
# ...                ...
# 5162                GO
# 5163                SP
# 5164                RS
# 5165                PR
# 5166                PE
#
# [5167 rows x 11 columns]

# %%
data.loc[data.ocorrencia_uf == 'SP']
# Out:
#       Unnamed: 0  codigo_ocorrencia  codigo_ocorrencia2  \
# 3              3              45401               45401
# 5              5              52243               52243
# 6              6              50713               50713
# 13            13              45408               45408
# 26            26              45410               45410
# ...          ...                ...                 ...
# 5148        5148              80441               80441
# 5157        5157              80453               80453
# 5158        5158              80454               80454
# 5161        5161              80456               80456
# 5163        5163              80452               80452
#
#      ocorrencia_classificacao  ocorrencia_cidade ocorrencia_uf  \
# 3                       GRAVE      SÃO SEBASTIÃO            SP
# 5                       GRAVE            UBATUBA            SP
# 6                       GRAVE           CAMPINAS            SP
# 13                      GRAVE           ELDORADO            SP
# 26                      GRAVE  BRAGANÇA PAULISTA            SP
# ...                       ...                ...           ...
# 5148                    GRAVE  BRAGANÇA PAULISTA            SP
# 5157                    GRAVE           CAMPINAS            SP
# 5158                    GRAVE          ARAÇATUBA            SP
# 5161                    GRAVE          SÃO PAULO            SP
# 5163                    GRAVE            MARACAÍ            SP
#
#      ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes  \
# 3                    ****     2012-01-06        17:00:00                   10
# 5                    ****     2012-01-06        14:30:00                   10
# 6                    SDAI     2012-01-07        18:15:00                   10
# 13                   ****     2012-01-11        13:45:00                   10
# 26                   SDVH     2012-01-21        23:30:00                   10
# ...                   ...            ...             ...                  ...
# 5148                 SDVH     2021-12-20        18:15:00                   10
# 5157                 SBKP     2021-12-29        09:00:00                   10
# 5158                 SBAU     2021-12-29        21:35:00                   10
# 5161                 SBSP     2021-12-30        13:15:00                   10
# 5163                *****     2021-12-31        09:30:00                   10
#
#      ocorrencia_uf_bkp
# 3                   SP
# 5                   SP
# 6                   SP
# 13                  SP
# 26                  SP
# ...                ...
# 5148                SP
# 5157                SP
# 5158                SP
# 5161                SP
# 5163                SP
#
# [1260 rows x 11 columns]

# %%
data
# Out:
#       Unnamed: 0  codigo_ocorrencia  codigo_ocorrencia2  \
# 0              0              52242               52242
# 1             20                 20                  20
# 2              2              45333               45333
# 3              3              45401               45401
# 4              4              45407               45407
# ...          ...                ...                 ...
# 5162        5162              80458               80458
# 5163        5163              80452               80452
# 5164        5164              80457               80457
# 5165        5165              80460               80460
# 5166        5166              80467               80467
#
#      ocorrencia_classificacao ocorrencia_cidade ocorrencia_uf  \
# 0                   INCIDENTE      PORTO ALEGRE            RS
# 1                          20                20            20
# 2                    ACIDENTE            VIAMÃO            RS
# 3                       GRAVE     SÃO SEBASTIÃO            SP
# 4                    ACIDENTE          SÃO SEPÉ            RS
# ...                       ...               ...           ...
# 5162                 ACIDENTE             JATAÍ            GO
# 5163                    GRAVE           MARACAÍ            SP
# 5164          INCIDENTE GRAVE     NOVO HAMBURGO            RS
# 5165                INCIDENTE          CURITIBA            PR
# 5166                INCIDENTE         PETROLINA            PE
#
#      ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes  \
# 0                             2012-01-05        20:27:00                   10
# 1                      20             20              20                   10
# 2                    ****     2012-01-06        13:00:00                   10
# 3                    ****     2012-01-06        17:00:00                   10
# 4                    ****     2012-01-06        16:30:00                   10
# ...                   ...            ...             ...                  ...
# 5162                 ####     2021-12-30        20:30:00                   10
# 5163                *****     2021-12-31        09:30:00                   10
# 5164                 SSNH     2021-12-31        11:59:00                   10
# 5165                 SBBI     2021-12-31        15:12:00                   10
# 5166                 SBPL     2021-12-31        20:30:00                   10
#
#      ocorrencia_uf_bkp
# 0                   RS
# 1                   20
# 2                   RS
# 3                   SP
# 4                   RS
# ...                ...
# 5162                GO
# 5163                SP
# 5164                RS
# 5165                PR
# 5166                PE
#
# [5167 rows x 11 columns]

# %%
data.head()
# Out:
#    Unnamed: 0  codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0           0              52242               52242                INCIDENTE
# 1          20                 20                  20                       20
# 2           2              45333               45333                 ACIDENTE
# 3           3              45401               45401                    GRAVE
# 4           4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                          2012-01-05
# 1                20            20                   20             20
# 2            VIAMÃO            RS                 ****     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 ****     2012-01-06
# 4          SÃO SEPÉ            RS                 ****     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes ocorrencia_uf_bkp
# 0        20:27:00                   10                RS
# 1              20                   10                20
# 2        13:00:00                   10                RS
# 3        17:00:00                   10                SP
# 4        16:30:00                   10                RS

# %%
data.loc[data.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
data.head()
# Out:
#    Unnamed: 0  codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0           0              52242               52242                INCIDENTE
# 1          20                 20                  20                       20
# 2           2              45333               45333                 ACIDENTE
# 3           3              45401               45401                    GRAVE
# 4           4              45407               45407                 ACIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      PORTO ALEGRE            RS                          2012-01-05
# 1                20            20                   20             20
# 2            VIAMÃO            RS                 <NA>     2012-01-06
# 3     SÃO SEBASTIÃO            SP                 <NA>     2012-01-06
# 4          SÃO SEPÉ            RS                 <NA>     2012-01-06
#
#   ocorrencia_hora  total_recomendacoes ocorrencia_uf_bkp
# 0        20:27:00                   10                RS
# 1              20                   10                20
# 2        13:00:00                   10                RS
# 3        17:00:00                   10                SP
# 4        16:30:00                   10                RS

# %%
data.replace(['**','###!','####','****','*****','NULL'], pd.NA, inplace=True)

# %%
data.isna().sum()
# Out:
# Unnamed: 0                     0
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# ocorrencia_uf_bkp              2
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                     0
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        1905
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# ocorrencia_uf_bkp              2
# dtype: int64

# %%
data.fillna(10, inplace=True)

# %%
data.isnull().sum()
