# %%
# Visualizando os dados da tabela de ocorrência do CENIPA
import pandas as pd
data = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
data.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              52242               52242               52242
# 1              45331               45331               45331
# 2              45333               45333               45333
# 3              45401               45401               45401
# 4              45407               45407               45407
# 5              52243               52243               52243
# 6              50713               50713               50713
# 7              45334               45334               45334
# 8              45391               45391               45391
# 9              52244               52244               52244
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               52242               52242                INCIDENTE
# 1               45331               45331                 ACIDENTE
# 2               45333               45333                 ACIDENTE
# 3               45401               45401                 ACIDENTE
# 4               45407               45407                 ACIDENTE
# 5               52243               52243                INCIDENTE
# 6               50713               50713          INCIDENTE GRAVE
# 7               45334               45334                INCIDENTE
# 8               45391               45391                 ACIDENTE
# 9               52244               52244                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude      ocorrencia_cidade  \
# 0                 NaN                  NaN           PORTO ALEGRE
# 1      -23.4355555556       -46.4730555556              GUARULHOS
# 2                 ***                  ***                 VIAMÃO
# 3                 ***                  ***          SÃO SEBASTIÃO
# 4                 ***                  ***               SÃO SEPÉ
# 5                 NaN                  NaN                UBATUBA
# 6                 ***                  ***               CAMPINAS
# 7                 NaN                  NaN                  BELÉM
# 8      -19.9133333333       -48.2930555556  CONCEIÇÃO DAS ALAGOAS
# 9                 ***                  ***             UBERLÂNDIA
#
#   ocorrencia_uf  ... ocorrencia_dia ocorrencia_hora  \
# 0            RS  ...     2012-01-05        20:27:00
# 1            SP  ...     2012-01-06        13:44:00
# 2            RS  ...     2012-01-06        13:00:00
# 3            SP  ...     2012-01-06        17:00:00
# 4            RS  ...     2012-01-06        16:30:00
# 5            SP  ...     2012-01-06        14:30:00
# 6            SP  ...     2012-01-07        18:15:00
# 7            PA  ...     2012-01-08        19:12:00
# 8            MG  ...     2012-01-08        16:00:00
# 9            MG  ...     2012-01-08        22:13:00
#
#   investigacao_aeronave_liberada investigacao_status  \
# 0                            ***          FINALIZADA
# 1                            SIM          FINALIZADA
# 2                            NaN          FINALIZADA
# 3                            ***                 NaN
# 4                            SIM          FINALIZADA
# 5                            ***          FINALIZADA
# 6                            SIM          FINALIZADA
# 7                            ***          FINALIZADA
# 8                            ***          FINALIZADA
# 9                            ***          FINALIZADA
#
#   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                         ***                            NÃO
# 1           A-582/CENIPA/2014                            SIM
# 2           A-070/CENIPA/2013                            SIM
# 3                         NaN                            NÃO
# 4           A-071/CENIPA/2013                            SIM
# 5                         ***                            NÃO
# 6          IG-184/CENIPA/2013                            SIM
# 7                         ***                            NÃO
# 8                   A DEFINIR                            NÃO
# 9                         ***                            NÃO
#
#   divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                       NaN                   0                          1
# 1                2016-09-01                   3                          1
# 2                2013-11-27                   0                          1
# 3                       NaN                   0                          1
# 4                2013-11-27                   0                          1
# 5                       NaN                   0                          1
# 6                2014-01-08                   0                          1
# 7                       NaN                   0                          1
# 8                       NaN                   0                          1
# 9                       NaN                   0                          1
#
#    ocorrencia_saida_pista
# 0                     NÃO
# 1                     NÃO
# 2                     NÃO
# 3                     NÃO
# 4                     NÃO
# 5                     NÃO
# 6                     NÃO
# 7                     NÃO
# 8                     NÃO
# 9                     NÃO
#
# [10 rows x 22 columns]

# %%
# Validando os dados extraídos da "Tabela de ocorrência" do CENIPA
import pandera as pa

# %%
# Imprimindo validação
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# c:\Users\patrick\Documents\Python_Challenges\FundamentosETLPython\data_validation.ipynb Cell 3' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/patrick/Documents/Python_Challenges/FundamentosETLPython/data_validation.ipynb#ch0000002?line=0'>1</a> # Imprimindo validação
# ----> <a href='vscode-notebook-cell:/c%3A/Users/patrick/Documents/Python_Challenges/FundamentosETLPython/data_validation.ipynb#ch0000002?line=1'>2</a> validate_data = schema(data)
#       <a href='vscode-notebook-cell:/c%3A/Users/patrick/Documents/Python_Challenges/FundamentosETLPython/data_validation.ipynb#ch0000002?line=2'>3</a> print(validate_data)
#
# File c:\Users\patrick\anaconda3\lib\site-packages\pandera\schemas.py:806, in DataFrameSchema.__call__(self, dataframe, head, tail, sample, random_state, lazy, inplace)
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=777'>778</a> def __call__(
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=778'>779</a>     self,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=779'>780</a>     dataframe: pd.DataFrame,
#    (...)
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=785'>786</a>     inplace: bool = False,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=786'>787</a> ):
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=787'>788</a>     """Alias for :func:`DataFrameSchema.validate` method.
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=788'>789</a>
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=789'>790</a>     :param pd.DataFrame dataframe: the dataframe to be validated.
#    (...)
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=803'>804</a>         otherwise creates a copy of the data.
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=804'>805</a>     """
# --> <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=805'>806</a>     return self.validate(
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=806'>807</a>         dataframe, head, tail, sample, random_state, lazy, inplace
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=807'>808</a>     )
#
# File c:\Users\patrick\anaconda3\lib\site-packages\pandera\schemas.py:515, in DataFrameSchema.validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=501'>502</a>     check_obj = check_obj.map_partitions(
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=502'>503</a>         self._validate,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=503'>504</a>         head=head,
#    (...)
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=509'>510</a>         meta=check_obj,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=510'>511</a>     )
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=512'>513</a>     return check_obj.pandera.add_schema(self)
# --> <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=514'>515</a> return self._validate(
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=515'>516</a>     check_obj=check_obj,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=516'>517</a>     head=head,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=517'>518</a>     tail=tail,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=518'>519</a>     sample=sample,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=519'>520</a>     random_state=random_state,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=520'>521</a>     lazy=lazy,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=521'>522</a>     inplace=inplace,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=522'>523</a> )
#
# File c:\Users\patrick\anaconda3\lib\site-packages\pandera\schemas.py:712, in DataFrameSchema._validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=709'>710</a>     check_results.append(check_utils.is_table(result))
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=710'>711</a> except errors.SchemaError as err:
# --> <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=711'>712</a>     error_handler.collect_error("schema_component_check", err)
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=712'>713</a> except errors.SchemaErrors as err:
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=713'>714</a>     for schema_error_dict in err.schema_errors:
#
# File c:\Users\patrick\anaconda3\lib\site-packages\pandera\error_handlers.py:32, in SchemaErrorHandler.collect_error(self, reason_code, schema_error, original_exc)
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=25'>26</a> """Collect schema error, raising exception if lazy is False.
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=26'>27</a>
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=27'>28</a> :param reason_code: string representing reason for error
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=28'>29</a> :param schema_error: ``SchemaError`` object.
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=29'>30</a> """
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=30'>31</a> if not self._lazy:
# ---> <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=31'>32</a>     raise schema_error from original_exc
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=33'>34</a> # delete data of validated object from SchemaError object to prevent
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=34'>35</a> # storing copies of the validated DataFrame/Series for every
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=35'>36</a> # SchemaError collected.
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=36'>37</a> del schema_error.data
#
# File c:\Users\patrick\anaconda3\lib\site-packages\pandera\schemas.py:704, in DataFrameSchema._validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=701'>702</a> for schema_component in schema_components:
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=702'>703</a>     try:
# --> <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=703'>704</a>         result = schema_component(
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=704'>705</a>             df_to_validate,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=705'>706</a>             lazy=lazy,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=706'>707</a>             # don't make a copy of the data
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=707'>708</a>             inplace=True,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=708'>709</a>         )
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=709'>710</a>         check_results.append(check_utils.is_table(result))
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=710'>711</a>     except errors.SchemaError as err:
#
# File c:\Users\patrick\anaconda3\lib\site-packages\pandera\schemas.py:2046, in SeriesSchemaBase.__call__(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2034'>2035</a> def __call__(
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2035'>2036</a>     self,
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2036'>2037</a>     check_obj: Union[pd.DataFrame, pd.Series],
#    (...)
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2042'>2043</a>     inplace: bool = False,
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2043'>2044</a> ) -> Union[pd.DataFrame, pd.Series]:
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2044'>2045</a>     """Alias for ``validate`` method."""
# -> <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2045'>2046</a>     return self.validate(
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2046'>2047</a>         check_obj, head, tail, sample, random_state, lazy, inplace
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2047'>2048</a>     )
#
# File c:\Users\patrick\anaconda3\lib\site-packages\pandera\schema_components.py:214, in Column.validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schema_components.py?line=209'>210</a>             validate_column(
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schema_components.py?line=210'>211</a>                 check_obj[column_name].iloc[:, [i]], column_name
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schema_components.py?line=211'>212</a>             )
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schema_components.py?line=212'>213</a>     else:
# --> <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schema_components.py?line=213'>214</a>         validate_column(check_obj, column_name)
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schema_components.py?line=215'>216</a> return check_obj
#
# File c:\Users\patrick\anaconda3\lib\site-packages\pandera\schema_components.py:187, in Column.validate.<locals>.validate_column(check_obj, column_name)
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schema_components.py?line=185'>186</a> def validate_column(check_obj, column_name):
# --> <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schema_components.py?line=186'>187</a>     super(Column, copy(self).set_name(column_name)).validate(
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schema_components.py?line=187'>188</a>         check_obj,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schema_components.py?line=188'>189</a>         head,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schema_components.py?line=189'>190</a>         tail,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schema_components.py?line=190'>191</a>         sample,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schema_components.py?line=191'>192</a>         random_state,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schema_components.py?line=192'>193</a>         lazy,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schema_components.py?line=193'>194</a>         inplace=inplace,
#     <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schema_components.py?line=194'>195</a>     )
#
# File c:\Users\patrick\anaconda3\lib\site-packages\pandera\schemas.py:2004, in SeriesSchemaBase.validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=1997'>1998</a>     check_results.append(
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=1998'>1999</a>         _handle_check_results(
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=1999'>2000</a>             self, check_index, check, check_obj, *check_args
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2000'>2001</a>         )
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2001'>2002</a>     )
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2002'>2003</a> except errors.SchemaError as err:
# -> <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2003'>2004</a>     error_handler.collect_error("dataframe_check", err)
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2004'>2005</a> except Exception as err:  # pylint: disable=broad-except
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2005'>2006</a>     # catch other exceptions that may occur when executing the
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2006'>2007</a>     # Check
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2007'>2008</a>     err_msg = f'"{err.args[0]}"' if len(err.args) > 0 else ""
#
# File c:\Users\patrick\anaconda3\lib\site-packages\pandera\error_handlers.py:32, in SchemaErrorHandler.collect_error(self, reason_code, schema_error, original_exc)
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=25'>26</a> """Collect schema error, raising exception if lazy is False.
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=26'>27</a>
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=27'>28</a> :param reason_code: string representing reason for error
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=28'>29</a> :param schema_error: ``SchemaError`` object.
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=29'>30</a> """
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=30'>31</a> if not self._lazy:
# ---> <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=31'>32</a>     raise schema_error from original_exc
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=33'>34</a> # delete data of validated object from SchemaError object to prevent
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=34'>35</a> # storing copies of the validated DataFrame/Series for every
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=35'>36</a> # SchemaError collected.
#      <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/error_handlers.py?line=36'>37</a> del schema_error.data
#
# File c:\Users\patrick\anaconda3\lib\site-packages\pandera\schemas.py:1999, in SeriesSchemaBase.validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=1995'>1996</a> for check_index, check in enumerate(self.checks):
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=1996'>1997</a>     try:
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=1997'>1998</a>         check_results.append(
# -> <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=1998'>1999</a>             _handle_check_results(
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=1999'>2000</a>                 self, check_index, check, check_obj, *check_args
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2000'>2001</a>             )
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2001'>2002</a>         )
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2002'>2003</a>     except errors.SchemaError as err:
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2003'>2004</a>         error_handler.collect_error("dataframe_check", err)
#
# File c:\Users\patrick\anaconda3\lib\site-packages\pandera\schemas.py:2385, in _handle_check_results(schema, check_index, check, check_obj, *check_args)
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2382'>2383</a>         warnings.warn(error_msg, UserWarning)
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2383'>2384</a>         return True
# -> <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2384'>2385</a>     raise errors.SchemaError(
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2385'>2386</a>         schema,
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2386'>2387</a>         check_obj,
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2387'>2388</a>         error_msg,
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2388'>2389</a>         failure_cases=failure_cases,
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2389'>2390</a>         check=check,
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2390'>2391</a>         check_index=check_index,
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2391'>2392</a>         check_output=check_result.check_output,
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2392'>2393</a>     )
#    <a href='file:///c%3A/Users/patrick/anaconda3/lib/site-packages/pandera/schemas.py?line=2393'>2394</a> return check_result.check_passed
#
# SchemaError: <Schema Column(name=ocorrencia_uf, type=DataType(str))> failed element-wise validator 0:
# <Check str_length: str_length(2, 2)>
# failure cases:
#    index failure_case
# 0   1099          ***
# 1   4728          ***
